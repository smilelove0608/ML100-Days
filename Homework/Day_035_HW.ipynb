# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %% [markdown]
# 參考文章:https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/404276/
# https://zhuanlan.zhihu.com/p/26729228
# https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRGRqTVhZU0JXVnVMVWxPR2dKSlRpZ0FQAQ?hl=en-IN&gl=IN&ceid=IN:en

# %% [markdown]
# 谷歌新聞所做的是，將每條新聞都標記為一個或多個類別，這樣它就會顯示在不同的類別之下。
# 同樣的新聞出現在“Technology”,“Latest” 等類別中，
# 因為它已經被分類為不同的標籤。從而使其成為一個多標籤分類問題。

# %%
from IPython.display import Image
Image(filename = 'C:\\Users\\mara0608\\Desktop\\ML100DAYS_ming\\DAY35\\google新聞圖片.png', width=500)
