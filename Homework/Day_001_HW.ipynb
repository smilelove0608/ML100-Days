# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 166.422

# %%
def mean_absolute_error(y,yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.196

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 166.422
# The Mean absolute error is 10.196

# %% [markdown]
# #作業2
# #想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 假設透過數據分析能知道特定區域的平均等待載客時間、熱門載客地點,
# 乘客上下車皆使用悠遊卡,利用公里數換算金額並直接支付,支付後會收到滿意度調查並提供LINE車隊好友資訊,
# 除了提供載客服務,也提供共乘服務(能事先預約或臨時共乘).
# 未來能直接在LINE叫車,優先配對.
# 系統自動預測出幾條路線,並藉由資料的增加或滿意度調查內容優化推薦路線.
#
# 提升業績的定義為每輛空車無載客時間需小於10分鐘.
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 資料含乘客資訊,因上下車皆須逼卡與滿意度調查,蒐集上下車地點,距離,時間等資訊,
# 每日的天氣,濕度,星期,時間也需蒐集與分析,在每台車上安裝偵測器蒐集資訊.
#
# 3. 蒐集而來的資料型態為何
# 數值,表格,圖形,照片,文字,地圖等.
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 驗證每台車的空車時間是否皆小於10分鐘,業績是否較前月成長.
# 看系統推薦的正確率,是否持續學習與進步.

# %% [markdown]
# #作業1#選擇Titanic: Machine Learning from Disaster
#
# 1. 你選的這組資料為何重要
# 鐵達尼造成眾多人死亡,藉由資料分析與預測哪些類別的人存活率較高.
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料含training set (train.csv)、test set (test.csv)、gender_submission.csv
# 資料來自kaggle,推測根據登船資訊與倖存者進行身分比對來蒐集資料.
#
# 3. 蒐集而來的資料型態為何
# 數值,文字
#
# 4. 這組資料想解決的問題如何評估
# 在test set隨機找一個乘客,預測他是否存活,並與真實數據比對,看正確性.
